# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import os
import pandas as pd

# %% [markdown]
# Read in the data from Lynne that ran the afterburner (not minion1016).

# %%
import lsst.sims.maf.db as db
import lsst.sims.maf.utils as mafUtils

dbfile = '/Volumes/Transcend/astro_lsst_01_1000_sqlite.db'
opsdb = db.OpsimDatabase(dbfile)
propIds, propTags = opsdb.fetchPropInfo()
wfdWhere = mafUtils.createSQLWhere('WFD', propTags)
sqlconstraint= wfdWhere   # get all filters
colnames = ['fieldID', 'fieldRA', 'fieldDec', 'rotTelPos', 'expMJD', 'night', 'filter',
            'hexDitherPerNightRA', 'hexDitherPerNightDec',
           'randomDitherFieldPerVisitRA', 'randomDitherFieldPerVisitDec', 'ditheredRotTelPos']
simdata = opsdb.fetchMetricData(colnames, sqlconstraint)

# %%
#simdata

# %% [markdown]
# # Check RandomDitherFieldPerVisit columns.

# %%
checkList= ['obsHistID', 'fieldRA', 'fieldDec', 'randomDitherFieldPerVisitRA', 'randomDitherFieldPerVisitDec']

indMin, indMax= 0,100

simList= []
for colType in checkList:
    simList.append(simdata[colType][indMin:indMax])
diffRA= simdata['fieldRA']-simdata['randomDitherFieldPerVisitRA']
diffDec= simdata['fieldDec']-simdata['randomDitherFieldPerVisitDec']

diffx= diffRA*np.cos(simdata['fieldDec'])

simList.append(diffRA[indMin:indMax])
simList.append(diffDec[indMin:indMax])
simList.append(diffx[indMin:indMax])
checkList.append('diffRA')
checkList.append('diffDec')
checkList.append('diffx')

pd.DataFrame(simList, checkList)
# Out:
#                                     0         1         2         3   \
# obsHistID                     1.000000  2.000000  3.000000  4.000000
# fieldRA                       1.256636  1.143387  1.100981  1.204558
# fieldDec                     -1.066865 -1.064843 -1.018929 -1.022575
# randomDitherFieldPerVisitRA   1.289052  1.081960  1.084959  1.163850
# randomDitherFieldPerVisitDec -1.077082 -1.065668 -1.043674 -1.032986
# diffRA                       -0.032416  0.061427  0.016022  0.040708
# diffDec                       0.010217  0.000825  0.024745  0.010411
# diffx                        -0.015653  0.029770  0.008400  0.021216
#
#                                     4         5         6         7   \
# obsHistID                     5.000000  6.000000  7.000000  8.000000
# fieldRA                       1.308717  1.412294  1.514146  1.613200
# fieldDec                     -1.022575 -1.018929 -1.011560 -1.000363
# randomDitherFieldPerVisitRA   1.319368  1.430050  1.519870  1.585950
# randomDitherFieldPerVisitDec -1.011864 -1.026602 -1.018266 -1.024684
# diffRA                       -0.010651 -0.017756 -0.005724  0.027250
# diffDec                      -0.010711  0.007673  0.006706  0.024321
# diffx                        -0.005551 -0.009309 -0.003037  0.014715
#
#                                     8          9      ...                90  \
# obsHistID                     9.000000  10.000000     ...       1427.000000
# fieldRA                       1.590056   1.481533     ...          2.615432
# fieldDec                     -1.048458  -1.058734     ...         -0.745078
# randomDitherFieldPerVisitRA   1.637490   1.519080     ...          2.617307
# randomDitherFieldPerVisitDec -1.047586  -1.040787     ...         -0.756034
# diffRA                       -0.047434  -0.037547     ...         -0.001875
# diffDec                      -0.000872  -0.017947     ...          0.010956
# diffx                        -0.023665  -0.018397     ...         -0.001378
#
#                                        91           92           93  \
# obsHistID                     1428.000000  1429.000000  1430.000000
# fieldRA                          2.642543     2.667641     2.578009
# fieldDec                        -0.695848    -0.645978    -0.698240
# randomDitherFieldPerVisitRA      2.640134     2.658042     2.562156
# randomDitherFieldPerVisitDec    -0.675447    -0.634896    -0.684254
# diffRA                           0.002409     0.009599     0.015853
# diffDec                         -0.020401    -0.011082    -0.013986
# diffx                            0.001849     0.007665     0.012143
#
#                                        94           95           96  \
# obsHistID                     1431.000000  1432.000000  1433.000000
# fieldRA                          2.547362     2.513273     2.474756
# fieldDec                        -0.746803    -0.794553    -0.841268
# randomDitherFieldPerVisitRA      2.564116     2.516159     2.445791
# randomDitherFieldPerVisitDec    -0.762138    -0.820635    -0.822695
# diffRA                          -0.016754    -0.002886     0.028965
# diffDec                          0.015335     0.026082    -0.018573
# diffx                           -0.012295    -0.002022     0.019306
#
#                                        97           98           99
# obsHistID                     1434.000000  1435.000000  1436.000000
# fieldRA                          2.430758     2.380240     2.322227
# fieldDec                        -0.886649    -0.930366    -0.972100
# randomDitherFieldPerVisitRA      2.428688     2.395499     2.326587
# randomDitherFieldPerVisitDec    -0.883720    -0.947833    -0.993148
# diffRA                           0.002070    -0.015259    -0.004360
# diffDec                         -0.002929     0.017467     0.021048
# diffx                            0.001308    -0.009118    -0.002457
#
# [8 rows x 100 columns]

# %% [markdown]
# ### Ok the dithers appears to be random and are implemented with every visit (comparing fieldRA with randomDitherFieldPerVisitRA and fieldDec with randomDitherFieldPerVisitDec)
#
# Check another chunk of the data:

# %%
checkList= ['obsHistID', 'fieldRA', 'fieldDec', 'randomDitherFieldPerVisitRA', 'randomDitherFieldPerVisitDec']
indMin, indMax= 170,190

simList= []
for colType in checkList:
    simList.append(simdata[colType][indMin:indMax])
    
simList.append(diffRA[indMin:indMax])
simList.append(diffDec[indMin:indMax])
simList.append(diffx[indMin:indMax])
checkList.append('diffRA')
checkList.append('diffDec')
checkList.append('diffx')

pd.DataFrame(simList, checkList)
# Out:
#                                        0            1            2   \
# obsHistID                     1507.000000  1508.000000  1509.000000
# fieldRA                          1.339153     1.421286     1.502661
# fieldDec                        -0.886649    -0.882847    -0.876368
# randomDitherFieldPerVisitRA      1.368070     1.424790     1.533778
# randomDitherFieldPerVisitDec    -0.906925    -0.899224    -0.889212
# diffRA                          -0.028917    -0.003504    -0.031117
# diffDec                          0.020276     0.016377     0.012844
# diffx                           -0.018276    -0.002225    -0.019913
#
#                                        3            4            5   \
# obsHistID                     1510.000000  1511.000000  1512.000000
# fieldRA                          1.582911     1.799299     1.792666
# fieldDec                        -0.867033    -0.966266    -1.015314
# randomDitherFieldPerVisitRA      1.562988     1.784290     1.746329
# randomDitherFieldPerVisitDec    -0.847613    -0.991268    -1.019223
# diffRA                           0.019923     0.015009     0.046337
# diffDec                         -0.019420     0.025002     0.003909
# diffx                            0.012892     0.008531     0.024436
#
#                                        6            7            8   \
# obsHistID                     1513.000000  1514.000000  2083.000000
# fieldRA                          1.784547     1.676483     2.651018
# fieldDec                        -1.064322    -1.082473     0.007847
# randomDitherFieldPerVisitRA      1.772721     1.705504     2.662081
# randomDitherFieldPerVisitDec    -1.073627    -1.071063     0.009588
# diffRA                           0.011826    -0.029021    -0.011063
# diffDec                          0.009305    -0.011410    -0.001741
# diffx                            0.005737    -0.013615    -0.011063
#
#                                        9            10           11  \
# obsHistID                     2084.000000  2085.000000  2086.000000
# fieldRA                          2.677385     2.649239     2.675318
# fieldDec                        -0.034089    -0.079882    -0.122655
# randomDitherFieldPerVisitRA      2.661650     2.656039     2.659091
# randomDitherFieldPerVisitDec    -0.039745    -0.096873    -0.123479
# diffRA                           0.015735    -0.006800     0.016227
# diffDec                          0.005656     0.016991     0.000824
# diffx                            0.015726    -0.006778     0.016105
#
#                                        12           13           14  \
# obsHistID                     2087.000000  2088.000000  2089.000000
# fieldRA                          2.647472     2.621351     2.594921
# fieldDec                        -0.169338    -0.125799    -0.082530
# randomDitherFieldPerVisitRA      2.656739     2.620881     2.615953
# randomDitherFieldPerVisitDec    -0.179974    -0.122962    -0.096390
# diffRA                          -0.009267     0.000470    -0.021032
# diffDec                          0.010636    -0.002837     0.013860
# diffx                           -0.009134     0.000466    -0.020960
#
#                                        15           16           17  \
# obsHistID                     2090.000000  2091.000000  2092.000000
# fieldRA                          2.622837     2.596066     2.568113
# fieldDec                        -0.037368     0.004882    -0.039526
# randomDitherFieldPerVisitRA      2.614008     2.579587     2.565002
# randomDitherFieldPerVisitDec    -0.063731     0.006700    -0.041446
# diffRA                           0.008829     0.016479     0.003111
# diffDec                          0.026363    -0.001818     0.001920
# diffx                            0.008823     0.016479     0.003109
#
#                                        18           19
# obsHistID                     2093.000000  2094.000000
# fieldRA                          2.540900     2.568902
# fieldDec                         0.003270     0.046914
# randomDitherFieldPerVisitRA      2.566270     2.540978
# randomDitherFieldPerVisitDec     0.009957     0.047328
# diffRA                          -0.025370     0.027924
# diffDec                         -0.006687    -0.000414
# diffx                           -0.025370     0.027893

# %% [markdown]
# ### Ok the dithers appears to be random and are implemented with every visit.
#
# Lets see how things match up with the MAF stacker. Will need to redefine the stacker  heresince the Dec column that will be added by the stacker already exists with the afterbuner ...

# %%
from lsst.sims.maf.stackers.baseStacker import BaseStacker
from lsst.sims.maf.stackers import inHexagon, wrapRADec
class randomFPVStacker(BaseStacker):
    """
    Same in as sim_maf but rename the added columns to have a maf tag.
    
    Randomly dither the RA and Dec pointings up to maxDither degrees from center,
    with a different offset for each field, for each visit.

    Parameters
    ----------
    raCol : str, optional
        The name of the RA column in the data.
        Default 'fieldRA'.
    decCol : str, optional
        The name of the Dec column in the data.
        Default 'fieldDec'.
    maxDither : float, optional
        The radius of the maximum dither offset, in degrees.
        Default 1.75 degrees.
    inHex : bool, optional
        If True, offsets are constrained to lie within a hexagon inscribed within the maxDither circle.
        If False, offsets can lie anywhere out to the edges of the maxDither circle.
        Default True.
    randomSeed : int, optional
        If set, then used as the random seed for the numpy random number generation for the dither offsets.
        Default None.
    """
    def __init__(self, raCol='fieldRA', decCol='fieldDec', maxDither=1.75,
                 inHex=True, randomSeed=None):
        """
        @ MaxDither in degrees
        """
        # Instantiate the RandomDither object and set internal variables.
        self.raCol = raCol
        self.decCol = decCol
        # Convert maxDither from degrees (internal units for ra/dec are radians)
        self.maxDither = np.radians(maxDither)
        self.inHex = inHex
        self.randomSeed = randomSeed
        # self.units used for plot labels
        self.units = ['rad', 'rad']
        # Values required for framework operation: this specifies the names of the new columns.
        self.colsAdded = ['maf_randomDitherFieldPerVisitRa', 'maf_randomDitherFieldPerVisitDec']
        # Values required for framework operation: this specifies the data columns required from the database.
        self.colsReq = [self.raCol, self.decCol]

    def _generateRandomOffsets(self, noffsets):
        xOut = np.array([], float)
        yOut = np.array([], float)
        maxTries = 100
        tries = 0
        while (len(xOut) < noffsets) and (tries < maxTries):
            dithersRad = np.sqrt(np.random.rand(noffsets * 2)) * self.maxDither
            dithersTheta = np.random.rand(noffsets * 2) * np.pi * 2.0
            xOff = dithersRad * np.cos(dithersTheta)
            yOff = dithersRad * np.sin(dithersTheta)
            if self.inHex:
                # Constrain dither offsets to be within hexagon.
                idx = inHexagon(xOff, yOff, self.maxDither)
                xOff = xOff[idx]
                yOff = yOff[idx]
            xOut = np.concatenate([xOut, xOff])
            yOut = np.concatenate([yOut, yOff])
            tries += 1
        if len(xOut) < noffsets:
            raise ValueError('Could not find enough random points within the hexagon in %d tries. '
                             'Try another random seed?' % (maxTries))
        self.xOff = xOut[0:noffsets]
        self.yOff = yOut[0:noffsets]

    def _run(self, simData):
        # Generate random numbers for dither, using defined seed value if desired.
        if self.randomSeed is not None:
            np.random.seed(self.randomSeed)
        # Generate the random dither values.
        noffsets = len(simData[self.raCol])
        self._generateRandomOffsets(noffsets)
        # Add to RA and dec values.
        simData['maf_randomDitherFieldPerVisitRa'] = (simData[self.raCol] +
                                                  self.xOff / np.cos(simData[self.decCol]))
        simData['maf_randomDitherFieldPerVisitDec'] = simData[self.decCol] + self.yOff
        # Wrap back into expected range.
        simData['maf_randomDitherFieldPerVisitRa'], simData['maf_randomDitherFieldPerVisitDec'] = \
            wrapRADec(simData['maf_randomDitherFieldPerVisitRa'], simData['maf_randomDitherFieldPerVisitDec'])
        return simData

# %%
s= randomFPVStacker(randomSeed=42)
simdata = s.run(simdata)

# %%
checkList= ['obsHistID', 'fieldRA', 'fieldDec', 'randomDitherFieldPerVisitRA',  'maf_randomDitherFieldPerVisitRa',
            'randomDitherFieldPerVisitDec', 'maf_randomDitherFieldPerVisitDec']

indMin, indMax= 0,100
simList= []
for colType in checkList:
    simList.append(simdata[colType][indMin:indMax])

maf_diffRA= simdata['fieldRA']-simdata['maf_randomDitherFieldPerVisitRa']
maf_diffDec= simdata['fieldDec']-simdata['maf_randomDitherFieldPerVisitDec']


maf_diffx= maf_diffRA*np.cos(simdata['fieldDec'])

simList.append(diffRA[indMin:indMax])
checkList.append('diffRA')

simList.append(maf_diffRA[indMin:indMax])
checkList.append('maf_diffRA')

simList.append(diffDec[indMin:indMax])
checkList.append('diffDec')

simList.append(maf_diffDec[indMin:indMax])
checkList.append('maf_diffDec')

simList.append(diffx[indMin:indMax])
checkList.append('diffx')

simList.append(maf_diffx[indMin:indMax])
checkList.append('maf_diffx')

pd.DataFrame(simList, checkList)
# Out:
#                                         0         1         2         3   \
# obsHistID                         1.000000  2.000000  3.000000  4.000000
# fieldRA                           1.256636  1.143387  1.100981  1.204558
# fieldDec                         -1.066865 -1.064843 -1.018929 -1.022575
# randomDitherFieldPerVisitRA       1.289052  1.081960  1.084959  1.163850
# maf_randomDitherFieldPerVisitRa   1.289054  1.118923  1.144537  1.219177
# randomDitherFieldPerVisitDec     -1.077082 -1.065668 -1.043674 -1.032986
# maf_randomDitherFieldPerVisitDec -1.077081 -1.041556 -1.025013 -1.013221
# diffRA                           -0.032416  0.061427  0.016022  0.040708
# maf_diffRA                       -0.032418  0.024464 -0.043556 -0.014619
# diffDec                           0.010217  0.000825  0.024745  0.010411
# maf_diffDec                       0.010216 -0.023287  0.006084 -0.009354
# diffx                            -0.015653  0.029770  0.008400  0.021216
# maf_diffx                        -0.015654  0.011856 -0.022836 -0.007619
#
#                                         4         5         6         7   \
# obsHistID                         5.000000  6.000000  7.000000  8.000000
# fieldRA                           1.308717  1.412294  1.514146  1.613200
# fieldDec                         -1.022575 -1.018929 -1.011560 -1.000363
# randomDitherFieldPerVisitRA       1.319368  1.430050  1.519870  1.585950
# maf_randomDitherFieldPerVisitRa   1.328938  1.426333  1.541460  1.658663
# randomDitherFieldPerVisitDec     -1.011864 -1.026602 -1.018266 -1.024684
# maf_randomDitherFieldPerVisitDec -1.016704 -1.019025 -1.030289 -1.007969
# diffRA                           -0.010651 -0.017756 -0.005724  0.027250
# maf_diffRA                       -0.020221 -0.014039 -0.027314 -0.045463
# diffDec                          -0.010711  0.007673  0.006706  0.024321
# maf_diffDec                      -0.005871  0.000096  0.018729  0.007606
# diffx                            -0.005551 -0.009309 -0.003037  0.014715
# maf_diffx                        -0.010539 -0.007360 -0.014491 -0.024550
#
#                                         8          9      ...       \
# obsHistID                         9.000000  10.000000     ...
# fieldRA                           1.590056   1.481533     ...
# fieldDec                         -1.048458  -1.058734     ...
# randomDitherFieldPerVisitRA       1.637490   1.519080     ...
# maf_randomDitherFieldPerVisitRa   1.582719   1.491469     ...
# randomDitherFieldPerVisitDec     -1.047586  -1.040787     ...
# maf_randomDitherFieldPerVisitDec -1.046049  -1.045528     ...
# diffRA                           -0.047434  -0.037547     ...
# maf_diffRA                        0.007337  -0.009936     ...
# diffDec                          -0.000872  -0.017947     ...
# maf_diffDec                      -0.002409  -0.013206     ...
# diffx                            -0.023665  -0.018397     ...
# maf_diffx                         0.003661  -0.004868     ...
#
#                                            90           91           92  \
# obsHistID                         1427.000000  1428.000000  1429.000000
# fieldRA                              2.615432     2.642543     2.667641
# fieldDec                            -0.745078    -0.695848    -0.645978
# randomDitherFieldPerVisitRA          2.617307     2.640134     2.658042
# maf_randomDitherFieldPerVisitRa      2.622451     2.662305     2.654024
# randomDitherFieldPerVisitDec        -0.756034    -0.675447    -0.634896
# maf_randomDitherFieldPerVisitDec    -0.763952    -0.717638    -0.655736
# diffRA                              -0.001875     0.002409     0.009599
# maf_diffRA                          -0.007019    -0.019762     0.013617
# diffDec                              0.010956    -0.020401    -0.011082
# maf_diffDec                          0.018874     0.021790     0.009758
# diffx                               -0.001378     0.001849     0.007665
# maf_diffx                           -0.005159    -0.015167     0.010874
#
#                                            93           94           95  \
# obsHistID                         1430.000000  1431.000000  1432.000000
# fieldRA                              2.578009     2.547362     2.513273
# fieldDec                            -0.698240    -0.746803    -0.794553
# randomDitherFieldPerVisitRA          2.562156     2.564116     2.516159
# maf_randomDitherFieldPerVisitRa      2.580504     2.548601     2.525647
# randomDitherFieldPerVisitDec        -0.684254    -0.762138    -0.820635
# maf_randomDitherFieldPerVisitDec    -0.689984    -0.730387    -0.785879
# diffRA                               0.015853    -0.016754    -0.002886
# maf_diffRA                          -0.002495    -0.001239    -0.012374
# diffDec                             -0.013986     0.015335     0.026082
# maf_diffDec                         -0.008256    -0.016416    -0.008674
# diffx                                0.012143    -0.012295    -0.002022
# maf_diffx                           -0.001911    -0.000909    -0.008669
#
#                                            96           97           98  \
# obsHistID                         1433.000000  1434.000000  1435.000000
# fieldRA                              2.474756     2.430758     2.380240
# fieldDec                            -0.841268    -0.886649    -0.930366
# randomDitherFieldPerVisitRA          2.445791     2.428688     2.395499
# maf_randomDitherFieldPerVisitRa      2.501235     2.441022     2.417238
# randomDitherFieldPerVisitDec        -0.822695    -0.883720    -0.947833
# maf_randomDitherFieldPerVisitDec    -0.857984    -0.875161    -0.934160
# diffRA                               0.028965     0.002070    -0.015259
# maf_diffRA                          -0.026479    -0.010264    -0.036998
# diffDec                             -0.018573    -0.002929     0.017467
# maf_diffDec                          0.016716    -0.011488     0.003794
# diffx                                0.019306     0.001308    -0.009118
# maf_diffx                           -0.017648    -0.006487    -0.022108
#
#                                            99
# obsHistID                         1436.000000
# fieldRA                              2.322227
# fieldDec                            -0.972100
# randomDitherFieldPerVisitRA          2.326587
# maf_randomDitherFieldPerVisitRa      2.304256
# randomDitherFieldPerVisitDec        -0.993148
# maf_randomDitherFieldPerVisitDec    -0.986032
# diffRA                              -0.004360
# maf_diffRA                           0.017971
# diffDec                              0.021048
# maf_diffDec                          0.013932
# diffx                               -0.002457
# maf_diffx                            0.010128
#
# [13 rows x 100 columns]

# %% [markdown]
# ###  Ok so the afterburner random dithers arent exactly the same as MAF version. Expected from random assignment?
#
#
# # Check HexDitherPerNight columns.

# %%
checkList= ['obsHistID', 'night', 'fieldRA', 'fieldDec', 'hexDitherPerNightRA', 'hexDitherPerNightDec']

indMin, indMax= 5,20
simList= []
for colType in checkList:
    simList.append(simdata[colType][indMin:indMax])
pd.DataFrame(simList, checkList)
# Out:
#                             0         1         2         3          4   \
# obsHistID             6.000000  7.000000  8.000000  9.000000  10.000000
# night                 0.000000  0.000000  0.000000  0.000000   0.000000
# fieldRA               1.412294  1.514146  1.613200  1.590056   1.481533
# fieldDec             -1.018929 -1.011560 -1.000363 -1.048458  -1.058734
# hexDitherPerNightRA   1.384622  1.486800  1.586333  1.560976   1.451923
# hexDitherPerNightDec -1.044058 -1.036689 -1.025492 -1.073587  -1.083863
#
#                              5          6          7          8           9   \
# obsHistID             11.000000  56.000000  57.000000  59.000000  721.000000
# night                  0.000000   0.000000   0.000000   0.000000    1.000000
# fieldRA                1.369885   1.031741   0.999128   0.923219    1.676483
# fieldDec              -1.064843  -1.058735  -1.011559  -1.048458   -1.082473
# hexDitherPerNightRA    1.339949   1.002131   0.971782   0.894139    1.653290
# hexDitherPerNightDec  -1.089972  -1.083864  -1.036688  -1.073587   -1.107602
#
#                               10          11          12          13  \
# obsHistID             722.000000  723.000000  724.000000  725.000000
# night                   1.000000    1.000000    1.000000    1.000000
# fieldRA                 1.694120    1.708513    1.720374    1.730248
# fieldDec               -1.033972   -0.985271   -0.936476   -0.887672
# hexDitherPerNightRA     1.672844    1.688824    1.702013    1.713010
# hexDitherPerNightDec   -1.059101   -1.010400   -0.961605   -0.912801
#
#                               14
# obsHistID             726.000000
# night                   1.000000
# fieldRA                 1.738574
# fieldDec               -0.838921
# hexDitherPerNightRA     1.722292
# hexDitherPerNightDec   -0.864050

# %% [markdown]
# ### Hm cant really tell much .. calculate the delRA, delDec (and delX since the hex lattice is in 2D Euclidean space)

# %%
diffRA= simdata['fieldRA']-simdata['hexDitherPerNightRA']
diffDec= simdata['fieldDec']-simdata['hexDitherPerNightDec']
diffx= diffRA*np.cos(simdata['fieldDec'])

simList.append(diffRA[indMin:indMax])
checkList.append('diffRA')

simList.append(diffDec[indMin:indMax])
checkList.append('diffDec')

simList.append(diffx[indMin:indMax])
checkList.append('diffx')

pd.DataFrame(simList, checkList)
# Out:
#                             0         1         2         3          4   \
# obsHistID             6.000000  7.000000  8.000000  9.000000  10.000000
# night                 0.000000  0.000000  0.000000  0.000000   0.000000
# fieldRA               1.412294  1.514146  1.613200  1.590056   1.481533
# fieldDec             -1.018929 -1.011560 -1.000363 -1.048458  -1.058734
# hexDitherPerNightRA   1.384622  1.486800  1.586333  1.560976   1.451923
# hexDitherPerNightDec -1.044058 -1.036689 -1.025492 -1.073587  -1.083863
# diffRA                0.027672  0.027346  0.026867  0.029080   0.029610
# diffDec               0.025129  0.025129  0.025129  0.025129   0.025129
# diffx                 0.014508  0.014508  0.014508  0.014508   0.014508
#
#                              5          6          7          8           9   \
# obsHistID             11.000000  56.000000  57.000000  59.000000  721.000000
# night                  0.000000   0.000000   0.000000   0.000000    1.000000
# fieldRA                1.369885   1.031741   0.999128   0.923219    1.676483
# fieldDec              -1.064843  -1.058735  -1.011559  -1.048458   -1.082473
# hexDitherPerNightRA    1.339949   1.002131   0.971782   0.894139    1.653290
# hexDitherPerNightDec  -1.089972  -1.083864  -1.036688  -1.073587   -1.107602
# diffRA                 0.029936   0.029610   0.027346   0.029080    0.023193
# diffDec                0.025129   0.025129   0.025129   0.025129    0.025129
# diffx                  0.014508   0.014508   0.014508   0.014508    0.010881
#
#                               10          11          12          13  \
# obsHistID             722.000000  723.000000  724.000000  725.000000
# night                   1.000000    1.000000    1.000000    1.000000
# fieldRA                 1.694120    1.708513    1.720374    1.730248
# fieldDec               -1.033972   -0.985271   -0.936476   -0.887672
# hexDitherPerNightRA     1.672844    1.688824    1.702013    1.713010
# hexDitherPerNightDec   -1.059101   -1.010400   -0.961605   -0.912801
# diffRA                  0.021276    0.019689    0.018361    0.017238
# diffDec                 0.025129    0.025129    0.025129    0.025129
# diffx                   0.010881    0.010881    0.010881    0.010881
#
#                               14
# obsHistID             726.000000
# night                   1.000000
# fieldRA                 1.738574
# fieldDec               -0.838921
# hexDitherPerNightRA     1.722292
# hexDitherPerNightDec   -0.864050
# diffRA                  0.016282
# diffDec                 0.025129
# diffx                   0.010881

# %% [markdown]
# ### Ok things appear to be working: diffDec, diffx remain the same for the same night. diffDec remains the same since we remain on same Dec of the lattice for a while, but diffX changes with night.
#
# Lets compare with the maf stacker. Will have to redefine it here again.

# %%
from lsst.sims.maf.stackers.ditherStackers import HexDitherFieldPerVisitStacker
class hexPNStacker(HexDitherFieldPerVisitStacker):
    """
    
    Same in as sim_maf but renamed added columns to have a maf tag.
    
    Use offsets from the hexagonal grid of 'hexdither', but visit each vertex sequentially.
    Sequential offset per night for all fields.

    Parameters
    ----------
    raCol : str, optional
        The name of the RA column in the data.
        Default 'fieldRA'.
    decCol : str, optional
        The name of the Dec column in the data.
        Default 'fieldDec'.
    fieldIdCol : str, optional
        The name of the fieldID column in the data.
        Used to identify fields which should be identified as the 'same'.
        Default 'fieldID'.
    nightCol : str, optional
        The name of the night column in the data.
        Default 'night'.
    maxDither : float, optional
        The radius of the maximum dither offset, in degrees.
        Default 1.75 degrees.
    inHex : bool, optional
        If True, offsets are constrained to lie within a hexagon inscribed within the maxDither circle.
        If False, offsets can lie anywhere out to the edges of the maxDither circle.
        Default True.
    """
    def __init__(self, raCol='fieldRA', decCol='fieldDec', fieldIdCol='fieldID',
                 nightCol='night', maxDither=1.75, inHex=True):
        """
        @ MaxDither in degrees
        """
        super(hexPNStacker, self).__init__(raCol=raCol, decCol=decCol, fieldIdCol=fieldIdCol,
                                                       maxDither=maxDither, inHex=inHex)
        self.nightCol = nightCol
        # Values required for framework operation: this specifies the names of the new columns.
        self.colsAdded = ['maf_hexDitherPerNightRa', 'maf_hexDitherPerNightDec']
        # Values required for framework operation: this specifies the data columns required from the database.
        self.colsReq.append(self.nightCol)

    def _run(self, simData):
        # Generate the spiral dither values
        self._generateHexOffsets()
        nights = np.unique(simData[self.nightCol])
        # Add to RA and dec values.
        vertexID = 0
        for n in nights:
            match = np.where(simData[self.nightCol] == n)[0]
            vertexID = vertexID % self.numPoints
            simData['maf_hexDitherPerNightRa'][match] = (simData[self.raCol][match] +
                                                     self.xOff[vertexID] /
                                                     np.cos(simData[self.decCol][match]))
            simData['maf_hexDitherPerNightDec'][match] = simData[self.decCol][match] + self.yOff[vertexID]
            vertexID += 1
        # Wrap RA/Dec into expected range.
        simData['maf_hexDitherPerNightRa'], simData['maf_hexDitherPerNightDec'] = \
            wrapRADec(simData['maf_hexDitherPerNightRa'], simData['maf_hexDitherPerNightDec'])
        return simData

# %%
s= hexPNStacker()
simdata = s.run(simdata)

# %%
checkList= ['obsHistID', 'night', 'fieldRA', 'fieldDec', 
            'hexDitherPerNightRA', 'maf_hexDitherPerNightRa',
            'hexDitherPerNightDec', 'maf_hexDitherPerNightDec']

indMin, indMax= 5,20
simList= []
for colType in checkList:
    simList.append(simdata[colType][indMin:indMax])
pd.DataFrame(simList, checkList)
# Out:
#                                 0         1         2         3          4   \
# obsHistID                 6.000000  7.000000  8.000000  9.000000  10.000000
# night                     0.000000  0.000000  0.000000  0.000000   0.000000
# fieldRA                   1.412294  1.514146  1.613200  1.590056   1.481533
# fieldDec                 -1.018929 -1.011560 -1.000363 -1.048458  -1.058734
# hexDitherPerNightRA       1.384622  1.486800  1.586333  1.560976   1.451923
# maf_hexDitherPerNightRa   1.384622  1.486800  1.586333  1.560976   1.451923
# hexDitherPerNightDec     -1.044058 -1.036689 -1.025492 -1.073587  -1.083863
# maf_hexDitherPerNightDec -1.044058 -1.036689 -1.025492 -1.073587  -1.083863
#
#                                  5          6          7          8   \
# obsHistID                 11.000000  56.000000  57.000000  59.000000
# night                      0.000000   0.000000   0.000000   0.000000
# fieldRA                    1.369885   1.031741   0.999128   0.923219
# fieldDec                  -1.064843  -1.058735  -1.011559  -1.048458
# hexDitherPerNightRA        1.339949   1.002131   0.971782   0.894139
# maf_hexDitherPerNightRa    1.339949   1.002131   0.971782   0.894139
# hexDitherPerNightDec      -1.089972  -1.083864  -1.036688  -1.073587
# maf_hexDitherPerNightDec  -1.089972  -1.083864  -1.036688  -1.073587
#
#                                   9           10          11          12  \
# obsHistID                 721.000000  722.000000  723.000000  724.000000
# night                       1.000000    1.000000    1.000000    1.000000
# fieldRA                     1.676483    1.694120    1.708513    1.720374
# fieldDec                   -1.082473   -1.033972   -0.985271   -0.936476
# hexDitherPerNightRA         1.653290    1.672844    1.688824    1.702013
# maf_hexDitherPerNightRa     1.653290    1.672843    1.688824    1.702013
# hexDitherPerNightDec       -1.107602   -1.059101   -1.010400   -0.961605
# maf_hexDitherPerNightDec   -1.107602   -1.059101   -1.010400   -0.961605
#
#                                   13          14
# obsHistID                 725.000000  726.000000
# night                       1.000000    1.000000
# fieldRA                     1.730248    1.738574
# fieldDec                   -0.887672   -0.838921
# hexDitherPerNightRA         1.713010    1.722292
# maf_hexDitherPerNightRa     1.713010    1.722292
# hexDitherPerNightDec       -0.912801   -0.864050
# maf_hexDitherPerNightDec   -0.912801   -0.864050

# %%
maf_diffRA= simdata['fieldRA']-simdata['maf_hexDitherPerNightRa']
maf_diffDec= simdata['fieldDec']-simdata['maf_hexDitherPerNightDec']
maf_diffx= maf_diffRA*np.cos(simdata['fieldDec'])

# %%
simList.append(diffRA[indMin:indMax])
checkList.append('diffRA')

simList.append(maf_diffRA[indMin:indMax])
checkList.append('maf_diffRA')

simList.append(diffDec[indMin:indMax])
checkList.append('diffDec')

simList.append(maf_diffDec[indMin:indMax])
checkList.append('maf_diffDec')

simList.append(diffx[indMin:indMax])
checkList.append('diffx')

simList.append(maf_diffx[indMin:indMax])
checkList.append('maf_diffx')

pd.DataFrame(simList, checkList)
# Out:
#                                 0         1         2         3          4   \
# obsHistID                 6.000000  7.000000  8.000000  9.000000  10.000000
# night                     0.000000  0.000000  0.000000  0.000000   0.000000
# fieldRA                   1.412294  1.514146  1.613200  1.590056   1.481533
# fieldDec                 -1.018929 -1.011560 -1.000363 -1.048458  -1.058734
# hexDitherPerNightRA       1.384622  1.486800  1.586333  1.560976   1.451923
# maf_hexDitherPerNightRa   1.384622  1.486800  1.586333  1.560976   1.451923
# hexDitherPerNightDec     -1.044058 -1.036689 -1.025492 -1.073587  -1.083863
# maf_hexDitherPerNightDec -1.044058 -1.036689 -1.025492 -1.073587  -1.083863
# diffRA                    0.027672  0.027346  0.026867  0.029080   0.029610
# maf_diffRA                0.027672  0.027346  0.026867  0.029080   0.029610
# diffDec                   0.025129  0.025129  0.025129  0.025129   0.025129
# maf_diffDec               0.025129  0.025129  0.025129  0.025129   0.025129
# diffx                     0.014508  0.014508  0.014508  0.014508   0.014508
# maf_diffx                 0.014508  0.014508  0.014508  0.014508   0.014508
#
#                                  5          6          7          8   \
# obsHistID                 11.000000  56.000000  57.000000  59.000000
# night                      0.000000   0.000000   0.000000   0.000000
# fieldRA                    1.369885   1.031741   0.999128   0.923219
# fieldDec                  -1.064843  -1.058735  -1.011559  -1.048458
# hexDitherPerNightRA        1.339949   1.002131   0.971782   0.894139
# maf_hexDitherPerNightRa    1.339949   1.002131   0.971782   0.894139
# hexDitherPerNightDec      -1.089972  -1.083864  -1.036688  -1.073587
# maf_hexDitherPerNightDec  -1.089972  -1.083864  -1.036688  -1.073587
# diffRA                     0.029936   0.029610   0.027346   0.029080
# maf_diffRA                 0.029936   0.029610   0.027346   0.029080
# diffDec                    0.025129   0.025129   0.025129   0.025129
# maf_diffDec                0.025129   0.025129   0.025129   0.025129
# diffx                      0.014508   0.014508   0.014508   0.014508
# maf_diffx                  0.014508   0.014508   0.014508   0.014508
#
#                                   9           10          11          12  \
# obsHistID                 721.000000  722.000000  723.000000  724.000000
# night                       1.000000    1.000000    1.000000    1.000000
# fieldRA                     1.676483    1.694120    1.708513    1.720374
# fieldDec                   -1.082473   -1.033972   -0.985271   -0.936476
# hexDitherPerNightRA         1.653290    1.672844    1.688824    1.702013
# maf_hexDitherPerNightRa     1.653290    1.672843    1.688824    1.702013
# hexDitherPerNightDec       -1.107602   -1.059101   -1.010400   -0.961605
# maf_hexDitherPerNightDec   -1.107602   -1.059101   -1.010400   -0.961605
# diffRA                      0.023193    0.021276    0.019689    0.018361
# maf_diffRA                  0.023193    0.021277    0.019689    0.018361
# diffDec                     0.025129    0.025129    0.025129    0.025129
# maf_diffDec                 0.025129    0.025129    0.025129    0.025129
# diffx                       0.010881    0.010881    0.010881    0.010881
# maf_diffx                   0.010881    0.010881    0.010881    0.010881
#
#                                   13          14
# obsHistID                 725.000000  726.000000
# night                       1.000000    1.000000
# fieldRA                     1.730248    1.738574
# fieldDec                   -0.887672   -0.838921
# hexDitherPerNightRA         1.713010    1.722292
# maf_hexDitherPerNightRa     1.713010    1.722292
# hexDitherPerNightDec       -0.912801   -0.864050
# maf_hexDitherPerNightDec   -0.912801   -0.864050
# diffRA                      0.017238    0.016282
# maf_diffRA                  0.017238    0.016282
# diffDec                     0.025129    0.025129
# maf_diffDec                 0.025129    0.025129
# diffx                       0.010881    0.010881
# maf_diffx                   0.010881    0.010881

# %% [markdown]
# ###  Ok with inHex=True in the afterburner, things look good!
#
#
# # Check RotationalDither columns.

# %%
checkList= ['filter', 'rotTelPos', 'ditheredRotTelPos']

indMin, indMax= 10, 315
simList= []
for colType in checkList:
    simList.append(simdata[colType][indMin:indMax])
pd.DataFrame(simList, checkList)
# Out:
#                         0        1         2         3        4         5    \
# filter                    y        y         y         y        z         z
# rotTelPos          0.034956  0.18474  0.189459  0.199213        0  0.002532
# ditheredRotTelPos  0.034956  0.18474  0.189459  0.199213 -1.08072  -1.07819
#
#                         6         7         8         9      ...          295  \
# filter                    z         z         z         z    ...            z
# rotTelPos          0.005301  0.007946  0.010448  0.012788    ...     0.242013
# ditheredRotTelPos  -1.07542  -1.07278  -1.07028  -1.06794    ...      1.39239
#
#                         296       297       298       299       300       301  \
# filter                    z         z         z         z         u         u
# rotTelPos          0.250938  0.262011  0.269214  0.277096  0.095303  0.112298
# ditheredRotTelPos   1.40131   1.41239   1.41959   1.42747  0.412965   0.42996
#
#                         302       303       304
# filter                    u         u         u
# rotTelPos          0.137025  0.152878  0.171209
# ditheredRotTelPos  0.454687   0.47054  0.488871
#
# [3 rows x 305 columns]

# %% [markdown]
# ### Ok so things appear to be working for until the first filter change. Need to know the add rotation dither to be sure of what happens afterwards.

# %%
diffRot= simdata['rotTelPos']-simdata['ditheredRotTelPos']
simList.append(diffRot[indMin:indMax])
checkList.append('diffRot')

# %%
pd.DataFrame(simList, checkList)
# Out:
#                         0        1         2         3        4         5    \
# filter                    y        y         y         y        z         z
# rotTelPos          0.034956  0.18474  0.189459  0.199213        0  0.002532
# ditheredRotTelPos  0.034956  0.18474  0.189459  0.199213 -1.08072  -1.07819
# diffRot                   0        0         0         0  1.08072   1.08072
#
#                         6         7         8         9      ...          295  \
# filter                    z         z         z         z    ...            z
# rotTelPos          0.005301  0.007946  0.010448  0.012788    ...     0.242013
# ditheredRotTelPos  -1.07542  -1.07278  -1.07028  -1.06794    ...      1.39239
# diffRot             1.08072   1.08072   1.08072   1.08072    ...     -1.15038
#
#                         296       297       298       299       300       301  \
# filter                    z         z         z         z         u         u
# rotTelPos          0.250938  0.262011  0.269214  0.277096  0.095303  0.112298
# ditheredRotTelPos   1.40131   1.41239   1.41959   1.42747  0.412965   0.42996
# diffRot            -1.15038  -1.15038  -1.15038  -1.15038 -0.317662 -0.317662
#
#                         302       303       304
# filter                    u         u         u
# rotTelPos          0.137025  0.152878  0.171209
# ditheredRotTelPos  0.454687   0.47054  0.488871
# diffRot           -0.317662 -0.317662 -0.317662
#
# [4 rows x 305 columns]

# %% [markdown]
# ### Ok the rotational dithers are now implemented after the filter change (diffRot remains the same in the same band but changes with filter change).

# %% [markdown]
# ## Ignore ..
#
# Lets see if an not-afterburner stacker could do what we want.

# %%
class rotStacker(BaseStacker):
    """
    Rotational Dithers.. tries to follow the afterburner code.
    """
    def __init__(self, rotCol='rotTelPos', filtCol= 'filter', randomSeed=None):
        """
        @ MaxDither in degrees
        """
        # Instantiate the RandomDither object and set internal variables.
        self.rotCol = rotCol
        self.filtCol= filtCol
        # Convert maxDither from degrees (internal units for ra/dec are radians)
        self.randomSeed = randomSeed
        # self.units used for plot labels
        self.units = ['rad']
        # Values required for framework operation: this specifies the names of the new columns.
        self.colsAdded = ['maf_ditheredRotTelPos']
        # Values required for framework operation: this specifies the data columns required from the database.
        self.colsReq = [self.rotCol, self.filtCol]

    def _run(self, simData):
        prevFilter= simData[self.filtCol][0]
        simData['maf_ditheredRotTelPos']= simData[self.rotCol][0]
        
        for filterBand in simData[self.filtCol][1:]:
            if (filterBand != prevFilter):    # i.e. if there is a filter change
                rotOffset= np.random.rand() * np.pi - np.pi/2
                prevFilter= filterBand
                simData['maf_ditheredRotTelPos']= simData[self.rotCol]+rotOffset
            else:
                simData['maf_ditheredRotTelPos']= simData[self.rotCol]
        return simData

# %%
s= rotStacker()
simdata = s.run(simdata)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-b0c76b3becfe> in <module>()
#       1 s= rotStacker()
# ----> 2 simdata = s.run(simdata)
#
# /Users/Humna/lsstRepos/sims_maf/python/lsst/sims/maf/stackers/baseStacker.pyc in run(self, simData)
#     139         simData=self._addStackers(simData)
#     140         # Run the method to calculate/add new data.
# --> 141         return self._run(simData)
#     142
#     143     def _run(self, simData):
#
# <ipython-input-19-d97923305752> in _run(self, simData)
#      29                 simData['maf_ditheredRotTelPos']= simData[self.rotCol]+rotOffset
#      30             else:
# ---> 31                 simData['maf_ditheredRotTelPos']= simData[self.rotCol]
#      32         return simData
#
# KeyboardInterrupt:

# %% [markdown]
# Either my code has issues or this is just supposed to take this long. Nvm running this for now. Know that there's a problem with the afterburner rotational dither column.

# %%
checkList= ['filter', 'rotTelPos', 'ditheredRotTelPos', 'maf_ditheredRotTelPos']

indMin, indMax= 10, 100
simList= []
for colType in checkList:
    simList.append(simdata[colType][indMin:indMax])
pd.DataFrame(simList, checkList)

# %%
maf_diffRot= simdata['rotTelPos']-simdata['maf_ditheredRotTelPos']
simList.append(maf_diffRot[indMin:indMax])
checkList.append('maf_diffRot')
pd.DataFrame(simList, checkList)
